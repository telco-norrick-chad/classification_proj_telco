# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import acquire as acq
import prepare as prep

# %%
total_df = prep.prep_telco(acq.get_telco_data())

# %%
total_df.columns
# Out:
# Index(['payment_type_id', 'internet_service_type_id', 'contract_type_id',
#        'customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'online_security',
#        'online_backup', 'device_protection', 'tech_support', 'streaming_tv',
#        'streaming_movies', 'paperless_billing', 'monthly_charges',
#        'total_charges', 'churn', 'contract_type', 'internet_service_type',
#        'payment_type', 'churn_encode', 'phone_id', 'movies_encode',
#        'tv_encode', 'streaming_services', 'online_security_encode',
#        'online_backup_encode', 'online_security_backup'],
#       dtype='object')

# %%
total_df[['online_security','online_backup', 'online_backup_encode', 'online_security_backup']]
# Out:
#           online_security        online_backup  online_backup_encode  \
# 0                      No                   No                     0
# 1                      No                   No                     0
# 2                     Yes                   No                     0
# 3                      No                   No                     0
# 4                     Yes                   No                     0
# 5                     Yes                   No                     0
# 6                     Yes                  Yes                     1
# 7                      No                   No                     0
# 8                      No                   No                     0
# 9                     Yes                   No                     0
# 10                     No                  Yes                     1
# 11                    Yes                  Yes                     1
# 12                    Yes                   No                     0
# 13                    Yes                   No                     0
# 14                    Yes                  Yes                     1
# 15                     No                  Yes                     1
# 16                    Yes                   No                     0
# 17                     No                   No                     0
# 18                     No                   No                     0
# 19                     No                   No                     0
# 20                     No                   No                     0
# 21                     No                  Yes                     1
# 22                     No                   No                     0
# 23                    Yes                  Yes                     1
# 24                     No                   No                     0
# 25                     No                   No                     0
# 26                    Yes                  Yes                     1
# 27                    Yes                  Yes                     1
# 28                     No                  Yes                     1
# 29                     No                   No                     0
# ...                   ...                  ...                   ...
# 7013  No internet service  No internet service                     0
# 7014  No internet service  No internet service                     0
# 7015  No internet service  No internet service                     0
# 7016  No internet service  No internet service                     0
# 7017  No internet service  No internet service                     0
# 7018  No internet service  No internet service                     0
# 7019  No internet service  No internet service                     0
# 7020  No internet service  No internet service                     0
# 7021  No internet service  No internet service                     0
# 7022  No internet service  No internet service                     0
# 7023  No internet service  No internet service                     0
# 7024  No internet service  No internet service                     0
# 7025  No internet service  No internet service                     0
# 7026  No internet service  No internet service                     0
# 7027  No internet service  No internet service                     0
# 7028  No internet service  No internet service                     0
# 7029  No internet service  No internet service                     0
# 7030  No internet service  No internet service                     0
# 7031  No internet service  No internet service                     0
# 7032  No internet service  No internet service                     0
# 7033  No internet service  No internet service                     0
# 7034  No internet service  No internet service                     0
# 7035  No internet service  No internet service                     0
# 7036  No internet service  No internet service                     0
# 7037  No internet service  No internet service                     0
# 7038  No internet service  No internet service                     0
# 7039  No internet service  No internet service                     0
# 7040  No internet service  No internet service                     0
# 7041  No internet service  No internet service                     0
# 7042  No internet service  No internet service                     0
#
#       online_security_backup
# 0                          0
# 1                          0
# 2                          1
# 3                          0
# 4                          1
# 5                          1
# 6                          2
# 7                          0
# 8                          0
# 9                          1
# 10                         1
# 11                         2
# 12                         1
# 13                         1
# 14                         2
# 15                         1
# 16                         1
# 17                         0
# 18                         0
# 19                         0
# 20                         0
# 21                         1
# 22                         0
# 23                         2
# 24                         0
# 25                         0
# 26                         2
# 27                         2
# 28                         1
# 29                         0
# ...                      ...
# 7013                       0
# 7014                       0
# 7015                       0
# 7016                       0
# 7017                       0
# 7018                       0
# 7019                       0
# 7020                       0
# 7021                       0
# 7022                       0
# 7023                       0
# 7024                       0
# 7025                       0
# 7026                       0
# 7027                       0
# 7028                       0
# 7029                       0
# 7030                       0
# 7031                       0
# 7032                       0
# 7033                       0
# 7034                       0
# 7035                       0
# 7036                       0
# 7037                       0
# 7038                       0
# 7039                       0
# 7040                       0
# 7041                       0
# 7042                       0
#
# [7043 rows x 4 columns]

# %%
#acq.peekatdata(df)
#df.head()

# %%
df = total_df[['churn_encode', 'monthly_charges']]

# %%
df.head()

# %% [markdown]
# ## Split into X's, y's and Train/Tests

# %%
X = df.drop('churn_encode',axis=1)
y = df[['churn_encode']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state = 123)

# %% [markdown]
# ## Logistic Regression fitting

# %%
logit = LogisticRegression()
logit.fit(X_train, y_train)
y_pred = logit.predict(X_train)
y_pred_proba = logit.predict_proba(X_train)

# %%
print('Columns: \n:', X_train.columns)
print('Coefficient: \n', logit.coef_)
print('Intercept: \n', logit.intercept_)

# %%
y_pred

# %% [markdown]
# #### Probability of Stay vs Churn

# %%
y_pred_proba

# %% [markdown]
# #### Accuracy

# %%
(y_train['churn_encode'] == y_pred).sum() / y_train.shape[0]
